# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor, DMatrix, plot_importance
from skopt import BayesSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import joblib

# %% [markdown]
# # Search for optimal parameters

# %%
# Set random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# %%
# Read data
data_path = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 4 columns).xlsx'
df = pd.read_excel(data_path)

# %%
# Filter out rows where the labels has missing values
df = df.dropna(subset=[df.columns[4]])

# %%
# Convert categorical column to dummy variables
df = pd.get_dummies(df, columns=[df.columns[6]])
df
# Out:
#            B<a>   P<a>       п1<a>  п1<c+a>     T1     C1      d      T  \
# 10   150.000000   30.0   75.252411    120.0  125.0  125.0   30.0  300.0
# 12   115.000000   55.0   99.119995    145.0   95.0  145.0   35.0  300.0
# 13   158.000000   88.0  128.101486    185.0  170.0  255.0   35.0  300.0
# 14   133.000000   62.0   81.000000    145.0   90.0  140.0   35.0  300.0
# 15   332.000000  155.0  202.000000    363.0  225.0  350.0    NaN  300.0
# 16   120.000000   60.0  104.046944    180.0  125.0    NaN   80.0  300.0
# 17    90.000000   80.0  110.000000    260.0  220.0  250.0   25.0  300.0
# 18   189.515793   98.0  147.879944    224.0  136.0    NaN   20.0  300.0
# 19   175.000000   68.0  120.000000    250.0  230.0    NaN   50.0  300.0
# 21   127.000000   96.0  162.802521    240.0  225.0    NaN  100.0  300.0
# 23   225.000000   90.0   98.151398    843.7  200.0  380.0    NaN  300.0
# 27   235.000000  100.0   95.224625    265.0  260.0  360.0   15.0  298.0
# 28   150.000000   70.0   95.224625    170.0  260.0  360.0   15.0  423.0
# 29   135.000000   60.0   95.224625    160.0  260.0  360.0   15.0  523.0
# 30   243.000000   59.0   91.000000    191.0  175.0  211.0   17.0  300.0
# 31    97.000000   30.0   86.847397    116.0  126.0  148.0   20.0  300.0
# 32   175.000000   70.0   79.873581    160.0  130.0  180.0   22.0  300.0
# 33   160.000000   70.0  100.000000    180.0  130.0  190.0   22.0  300.0
# 34   133.000000   62.0   81.000000    145.0   90.0  140.0    NaN  300.0
# 35    84.000000   42.0   72.000000    250.0  193.0  317.0    NaN  300.0
# 36   128.000000   69.0  118.767601    180.0  230.0  260.0   20.0  300.0
# 38   187.000000  100.0  116.175781    231.0  162.0  275.0   15.0  300.0
# 39   181.500000   90.6  109.923828    423.5  110.0  165.0   84.0  300.0
# 40   155.000000   98.0   89.981804    160.0  100.0  140.0   22.0  300.0
# 41   291.000000   75.0  189.832474    731.0  258.0  555.0   25.0  300.0
# 44   112.000000   34.0   88.796562    185.0  118.0  178.0   30.7  300.0
# 54   301.639709  235.0  620.000000    565.0  570.0  545.0    NaN  298.0
# 107  494.000000  395.0  395.000000    494.0  502.0    NaN    1.0  300.0
# 108  513.000000  395.0  395.000000    612.0  502.0    NaN    1.0  300.0
#
#            έ    `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al    ~Mo  \
# 10       NaN  2.447  2.790  4.00  0.0000  0.080  0.010  0.0150  0.058  0.032
# 12   0.00066  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 13   0.00066  2.447  2.790  4.00  0.0000  0.100  0.250  0.0100  1.450  0.040
# 14       NaN  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 15   0.00010  2.447  2.790  4.00  0.0000  0.009  0.220  0.0024  1.276  0.112
# 16       NaN  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 17       NaN  2.447  2.790  4.00  0.0000  0.005  0.060  0.0015  0.348  0.064
# 18   0.00100  2.447  2.790  4.00  0.0000  0.001  0.001  0.0010  0.006  0.000
# 19       NaN  2.447  2.790  4.00  0.0000  0.070  0.120  0.0013  0.696  0.000
# 21       NaN  2.447  2.790  4.00  0.0000  0.015  0.170  0.0150  1.003  0.093
# 23   0.00030  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 27   0.00100  2.447  2.790  4.00  0.0000  0.100  0.250  0.0150  1.450  0.032
# 28   0.00100  2.447  2.790  4.00  0.0000  0.100  0.250  0.0150  1.450  0.032
# 29   0.00100  2.447  2.790  4.00  0.0000  0.100  0.250  0.0150  1.450  0.032
# 30   0.00100  2.447  2.790  4.00  0.0000  0.100  0.250  0.0100  1.450  0.000
# 31   0.00100  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 32   0.10000  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 33   0.10000  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 34   0.00100  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 35   0.00100  2.447  2.790  4.00  0.0000  0.080  0.056  0.0120  0.116  0.000
# 36   0.00067  2.447  2.790  4.00  0.0000  0.080  0.020  0.0150  0.116  0.048
# 38   0.00010  2.447  2.790  4.00  0.0000  0.080  0.250  0.0150  1.450  0.048
# 39   0.00033  2.447  2.790  4.00  0.0000  0.040  0.060  0.0150  0.348  0.032
# 40   0.00500  2.447  2.790  4.00  0.0000  0.080  0.250  0.0150  1.450  0.000
# 41   0.00100  2.447  2.790  4.00  0.0000  0.010  0.130  0.0020  0.754  0.060
# 44   0.00500  2.447  2.790  4.00  0.0000  0.080  0.180  0.0150  1.044  0.032
# 54   0.00500  2.421  2.744  3.97 -0.0063  0.040  0.120  0.0005  3.696  3.024
# 107  0.00050  2.401  2.753  3.93 -0.0114  0.008  0.110  0.0005  6.719  4.868
# 108  0.00050  2.401  2.753  3.93 -0.0114  0.008  0.110  0.0005  6.719  4.868
#
#        M_C    M_T
# 10   False   True
# 12   False   True
# 13   False   True
# 14   False   True
# 15   False   True
# 16   False   True
# 17   False   True
# 18   False   True
# 19    True  False
# 21   False   True
# 23    True  False
# 27    True  False
# 28    True  False
# 29    True  False
# 30   False   True
# 31    True  False
# 32   False   True
# 33   False   True
# 34   False   True
# 35   False   True
# 36   False   True
# 38    True  False
# 39   False   True
# 40    True  False
# 41   False   True
# 44    True  False
# 54    True  False
# 107  False   True
# 108   True  False

# %%
X = df.iloc[:, 6:]
y = df.iloc[:,4]

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
# Define Pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Normalized data
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=random_seed))
])

# %%
# Define parameter space
param_space = {
    'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
    'xgb__n_estimators': (50, 300),
    'xgb__max_depth': (2, 8),
    'xgb__min_child_weight': (1, 10),
    'xgb__subsample': (0.5, 1.0, 'uniform'),
    'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
    'xgb__gamma': (0, 5),
    'xgb__reg_alpha': (0, 1),
    'xgb__reg_lambda': (0, 1)
}

# %%
# Parametric search using BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=pipeline,
    search_spaces=param_space,
    scoring='neg_mean_squared_error',
    cv=KFold(n_splits=5, shuffle=True, random_state=random_seed), 
    n_iter=50,
    n_jobs=-1,
    random_state=random_seed
)

# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                         ('xgb',
#                                          XGBRegressor(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       g...
#               n_jobs=-1, random_state=42, scoring='neg_mean_squared_error',
#               search_spaces={'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
#                              'xgb__gamma': (0, 5),
#                              'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
#                              'xgb__max_depth': (2, 8),
#                              'xgb__min_child_weight': (1, 10),
#                              'xgb__n_estimators': (50, 300),
#                              'xgb__reg_alpha': (0, 1),
#                              'xgb__reg_lambda': (0, 1),
#                              'xgb__subsample': (0.5, 1.0, 'uniform')})

# %%
# Output the best parameters
print("Best params:", bayes_search.best_params_)
print("Best score of train:", bayes_search.best_score_)
print("Best score of test (R²):", r2_score(y_test, bayes_search.predict(X_test)))
# Out:
# Best params: OrderedDict([('xgb__colsample_bytree', 0.5), ('xgb__gamma', 0), ('xgb__learning_rate', 0.01), ('xgb__max_depth', 5), ('xgb__min_child_weight', 1), ('xgb__n_estimators', 300), ('xgb__reg_alpha', 1), ('xgb__reg_lambda', 0), ('xgb__subsample', 0.7805383291904082)])
# Best score of train: -4531.763570728769
# Best score of test (R²): 0.8622234566113056

# %% [markdown]
# # Build the model

# %%
# Get the best parameters for further modeling
best_params = bayes_search.best_params_
xgb_best_params = {k.split('__')[1]: v for k, v in best_params.items()}

# %%
# Convert data to DMatrix format for XGBoost training
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Train XGBoost model using the best parameters
num_round = 500
xgb_model = xgb.train(xgb_best_params, dtrain, num_round, evals=[(dtest, 'eval')], verbose_eval=False)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [10:15:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the model to a file
filename = 'xgboost_model_T1_0926(original).sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %% [markdown]
# # Predicted results using the original data

# %%
# Predict on the test set
y_pred = xgb_model.predict(dtest)

# %%
# Calculate and print the RMSE and R² on the test set
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f'Test RMSE: {rmse}')
print(f'R² score: {r2}')
# Out:
# Test RMSE: 47.40594709555503
# R² score: 0.8628577234038967

# %%
# Obtain residuals for training and test sets
y_pred_train = xgb_model.predict(dtrain)
residuals_train = y_train.values - y_pred_train
residuals_test = y_test.values - y_pred

# Plot residuals
plt.figure(figsize=(8, 6))
plt.ylim(-100, 100)
plt.scatter(x=y_train, y=residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(x=y_test, y=residuals_test, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of T1 (MPa)', fontsize=18)
plt.ylabel('Residuals (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Residual plot of original T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of T1 (MPa)', fontsize=18)
plt.ylabel('Predicted (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='blue', lw=2, linestyle='--')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Predicted vs Actual of original T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Perform cross-validation and obtain performance metrics
cv_result = xgb.cv(xgb_best_params, dtrain, num_round, nfold=5)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [10:15:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cv_result) + 1), cv_result['train-rmse-mean'], c="blue", label='Train RMSE')
plt.plot(range(1, len(cv_result) + 1), cv_result['test-rmse-mean'], c="red", label='Test RMSE')
plt.xlabel('Number of Boosting Rounds of T1', fontsize=18)
plt.ylabel('RMSE', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize="x-large")
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\XGBoost Learning Curve of original T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot feature importance
fig, ax = plt.subplots(figsize=(8, 6))
plot_importance(xgb_model, ax=ax)
plt.xlabel('F score of T1', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Feature importance of original T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fill in empty data using the initial model

# %%
# Load the saved model for prediction
model_filename = 'xgboost_model_T1_0926(original).sav'
xgb_model = joblib.load(model_filename)

# %%
# Read the Excel file with missing labels
df_missing = pd.read_excel(data_path)

# %%
# Identify rows with missing labels in the B<a> column
missing_mask = df_missing[df_missing.columns[4]].isna()

# %%
# Filter rows with missing labels
df_to_predict = df_missing[missing_mask]
df_to_predict
# Out:
#            B<a>        P<a>        п1<a>     п1<c+a>  T1  C1  M      d      T  \
# 0    209.000000  181.000000   129.709366  474.000000 NaN NaN  C    NaN  300.0
# 1    238.396133  103.283859   100.437004  607.500000 NaN NaN  C    NaN  300.0
# 2    230.900131  139.100000   803.092407  337.744080 NaN NaN  C   2.80  300.0
# 3    234.993423  174.700000   322.611359  337.744080 NaN NaN  C   1.95  300.0
# 4    234.424667  220.100000   322.611359  337.744080 NaN NaN  C   0.97  300.0
# ..          ...         ...          ...         ...  ..  .. ..    ...    ...
# 138  329.900000  277.200000  1167.000000  579.691650 NaN NaN  T   4.21  300.0
# 139  206.000000  190.000000   425.678223  619.000000 NaN NaN  T    NaN  300.0
# 140  392.000000  329.000000   271.167480  874.000000 NaN NaN  T  20.00  293.0
# 141  275.800000  206.900000   248.200000  523.197205 NaN NaN  T    NaN  300.0
# 142  450.000000  420.000000  1028.751587  347.500885 NaN NaN  T   1.00  300.0
#
#            έ    `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al     ~Mo
# 0    0.00025  2.447  2.790  4.00  0.0000  0.012  0.070  0.0150  0.406   0.056
# 1    0.00010  2.447  2.790  4.00  0.0000  0.080  0.180  0.0150  1.044   0.032
# 2    0.03000  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032
# 3    0.00500  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032
# 4    0.00500  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032
# ..       ...    ...    ...   ...     ...    ...    ...     ...    ...     ...
# 138  0.00050  2.422  2.755  3.91 -0.0054  0.050  0.100  0.0125  7.212   4.870
# 139  0.00500  2.423  2.761  3.92 -0.0065  0.005  0.100  0.0010  6.713   3.247
# 140  0.00100  2.414  2.754  3.92 -0.0087  0.080  0.015  0.0120  7.006   4.560
# 141  0.00025  2.407  2.743  3.89 -0.0112  0.023  0.140  0.0013  8.712   2.200
# 142  0.00010  2.356  2.770  4.09 -0.0159  0.011  0.110  0.0010  3.678  15.136
#
# [114 rows x 19 columns]

# %%
# One-hot encoding for non-numeric feature in df_to_predict
df_to_predict = pd.get_dummies(df_to_predict, columns=[df_to_predict.columns[6]])
df_to_predict
# Out:
#            B<a>        P<a>        п1<a>     п1<c+a>  T1  C1      d      T  \
# 0    209.000000  181.000000   129.709366  474.000000 NaN NaN    NaN  300.0
# 1    238.396133  103.283859   100.437004  607.500000 NaN NaN    NaN  300.0
# 2    230.900131  139.100000   803.092407  337.744080 NaN NaN   2.80  300.0
# 3    234.993423  174.700000   322.611359  337.744080 NaN NaN   1.95  300.0
# 4    234.424667  220.100000   322.611359  337.744080 NaN NaN   0.97  300.0
# ..          ...         ...          ...         ...  ..  ..    ...    ...
# 138  329.900000  277.200000  1167.000000  579.691650 NaN NaN   4.21  300.0
# 139  206.000000  190.000000   425.678223  619.000000 NaN NaN    NaN  300.0
# 140  392.000000  329.000000   271.167480  874.000000 NaN NaN  20.00  293.0
# 141  275.800000  206.900000   248.200000  523.197205 NaN NaN    NaN  300.0
# 142  450.000000  420.000000  1028.751587  347.500885 NaN NaN   1.00  300.0
#
#            έ    `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al     ~Mo  \
# 0    0.00025  2.447  2.790  4.00  0.0000  0.012  0.070  0.0150  0.406   0.056
# 1    0.00010  2.447  2.790  4.00  0.0000  0.080  0.180  0.0150  1.044   0.032
# 2    0.03000  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032
# 3    0.00500  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032
# 4    0.00500  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032
# ..       ...    ...    ...   ...     ...    ...    ...     ...    ...     ...
# 138  0.00050  2.422  2.755  3.91 -0.0054  0.050  0.100  0.0125  7.212   4.870
# 139  0.00500  2.423  2.761  3.92 -0.0065  0.005  0.100  0.0010  6.713   3.247
# 140  0.00100  2.414  2.754  3.92 -0.0087  0.080  0.015  0.0120  7.006   4.560
# 141  0.00025  2.407  2.743  3.89 -0.0112  0.023  0.140  0.0013  8.712   2.200
# 142  0.00010  2.356  2.770  4.09 -0.0159  0.011  0.110  0.0010  3.678  15.136
#
#        M_C    M_T
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False
# 4     True  False
# ..     ...    ...
# 138  False   True
# 139  False   True
# 140  False   True
# 141  False   True
# 142  False   True
#
# [114 rows x 20 columns]

# %%
# Align the columns of the filled data (df_train) and data to predict (df_to_predict)
df, df_to_predict = df.align(df_to_predict, join='left', axis=1, fill_value=0)

# %%
# Extract features for prediction, excluding the label column
X_to_predict = df_to_predict.iloc[:, 6:].to_numpy()

# %%
# Ensure the feature order matches the trained model
feature_names = df.columns[6:].tolist()

# %%
# Make predictions using the model
d_matrix = xgb.DMatrix(X_to_predict, feature_names=feature_names)
y_pred = xgb_model.predict(d_matrix)

# %%
# Fill the missing labels with the predicted values
df_missing.loc[missing_mask, df_missing.columns[4]] = y_pred

# %%
# Save the dataframe with filled labels back to the Excel file
output_file = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 5 columns).xlsx'
df_missing.to_excel(output_file, index=False)

# %% [markdown]
# # Rebulid model using secondary data

# %%
# Read data again
data_path = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 5 columns).xlsx'
df = pd.read_excel(data_path)

# %%
# Convert categorical column to dummy variables
df = pd.get_dummies(df, columns=[df.columns[6]])
df
# Out:
#            B<a>        P<a>        п1<a>     п1<c+a>          T1  C1      d  \
# 0    209.000000  181.000000   129.709366  474.000000  223.175171 NaN    NaN
# 1    238.396133  103.283859   100.437004  607.500000  178.811584 NaN    NaN
# 2    230.900131  139.100000   803.092407  337.744080  186.461655 NaN   2.80
# 3    234.993423  174.700000   322.611359  337.744080  186.461655 NaN   1.95
# 4    234.424667  220.100000   322.611359  337.744080  186.461655 NaN   0.97
# ..          ...         ...          ...         ...         ...  ..    ...
# 138  329.900000  277.200000  1167.000000  579.691650  486.147339 NaN   4.21
# 139  206.000000  190.000000   425.678223  619.000000  507.494293 NaN    NaN
# 140  392.000000  329.000000   271.167480  874.000000  536.698975 NaN  20.00
# 141  275.800000  206.900000   248.200000  523.197205  525.335388 NaN    NaN
# 142  450.000000  420.000000  1028.751587  347.500885  444.004669 NaN   1.00
#
#          T        έ    `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al  \
# 0    300.0  0.00025  2.447  2.790  4.00  0.0000  0.012  0.070  0.0150  0.406
# 1    300.0  0.00010  2.447  2.790  4.00  0.0000  0.080  0.180  0.0150  1.044
# 2    300.0  0.03000  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870
# 3    300.0  0.00500  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870
# 4    300.0  0.00500  2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870
# ..     ...      ...    ...    ...   ...     ...    ...    ...     ...    ...
# 138  300.0  0.00050  2.422  2.755  3.91 -0.0054  0.050  0.100  0.0125  7.212
# 139  300.0  0.00500  2.423  2.761  3.92 -0.0065  0.005  0.100  0.0010  6.713
# 140  293.0  0.00100  2.414  2.754  3.92 -0.0087  0.080  0.015  0.0120  7.006
# 141  300.0  0.00025  2.407  2.743  3.89 -0.0112  0.023  0.140  0.0013  8.712
# 142  300.0  0.00010  2.356  2.770  4.09 -0.0159  0.011  0.110  0.0010  3.678
#
#         ~Mo    M_C    M_T
# 0     0.056   True  False
# 1     0.032   True  False
# 2     0.032   True  False
# 3     0.032   True  False
# 4     0.032   True  False
# ..      ...    ...    ...
# 138   4.870  False   True
# 139   3.247  False   True
# 140   4.560  False   True
# 141   2.200  False   True
# 142  15.136  False   True
#
# [143 rows x 20 columns]

# %%
X = df.iloc[:, 6:]
y = df.iloc[:,4]

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
# Define Pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Normalized data
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=random_seed))
])

# %%
# Define parameter space
param_space = {
    'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
    'xgb__n_estimators': (50, 300),
    'xgb__max_depth': (2, 8),
    'xgb__min_child_weight': (1, 10),
    'xgb__subsample': (0.5, 1.0, 'uniform'),
    'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
    'xgb__gamma': (0, 5),
    'xgb__reg_alpha': (0, 1),
    'xgb__reg_lambda': (0, 1)
}

# %%
# Parametric search using BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=pipeline,
    search_spaces=param_space,
    scoring='neg_mean_squared_error',
    cv=KFold(n_splits=5, shuffle=True, random_state=random_seed), 
    n_iter=50,
    n_jobs=-1,
    random_state=random_seed
)

# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                         ('xgb',
#                                          XGBRegressor(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       g...
#               n_jobs=-1, random_state=42, scoring='neg_mean_squared_error',
#               search_spaces={'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
#                              'xgb__gamma': (0, 5),
#                              'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
#                              'xgb__max_depth': (2, 8),
#                              'xgb__min_child_weight': (1, 10),
#                              'xgb__n_estimators': (50, 300),
#                              'xgb__reg_alpha': (0, 1),
#                              'xgb__reg_lambda': (0, 1),
#                              'xgb__subsample': (0.5, 1.0, 'uniform')})

# %%
# Output the best parameters
print("Best params:", bayes_search.best_params_)
print("Best score of train:", bayes_search.best_score_)
print("Best score of test (R²):", r2_score(y_test, bayes_search.predict(X_test)))
# Out:
# Best params: OrderedDict([('xgb__colsample_bytree', 0.5), ('xgb__gamma', 5), ('xgb__learning_rate', 0.05128016108046837), ('xgb__max_depth', 8), ('xgb__min_child_weight', 1), ('xgb__n_estimators', 300), ('xgb__reg_alpha', 1), ('xgb__reg_lambda', 0), ('xgb__subsample', 0.5)])
# Best score of train: -374.29743313203596
# Best score of test (R²): 0.9814293106157979

# %%
# Get the best parameters for further modeling
best_params = bayes_search.best_params_
xgb_best_params = {k.split('__')[1]: v for k, v in best_params.items()}

# %%
# Convert data to DMatrix format for XGBoost training
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Train XGBoost model using the best parameters
num_round = 500
xgb_model = xgb.train(xgb_best_params, dtrain, num_round, evals=[(dtest, 'eval')], verbose_eval=False)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [10:17:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the model to another file
filename = 'xgboost_model_T1_0926(secondary).sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %%
# Predict on the test set
y_pred = xgb_model.predict(dtest)

# %%
# Calculate and print the RMSE and R² on the test set
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f'Test RMSE: {rmse}')
print(f'R² score: {r2}')
# Out:
# Test RMSE: 21.331969089067787
# R² score: 0.9832576840814482

# %%
# Obtain residuals for training and test sets
y_pred_train = xgb_model.predict(dtrain)
residuals_train = y_train.values - y_pred_train
residuals_test = y_test.values - y_pred

# Plot residuals
plt.figure(figsize=(8, 6))
plt.ylim(-100, 100)
plt.scatter(x=y_train, y=residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(x=y_test, y=residuals_test, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of T1 (MPa)', fontsize=18)
plt.ylabel('Residuals (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Residual plot of secondary T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of T1 (MPa)', fontsize=18)
plt.ylabel('Predicted (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='blue', lw=2, linestyle='--')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Predicted vs Actual of secondary T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Perform cross-validation and obtain performance metrics
cv_result = xgb.cv(xgb_best_params, dtrain, num_round, nfold=5)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [10:17:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cv_result) + 1), cv_result['train-rmse-mean'], c="blue", label='Train RMSE')
plt.plot(range(1, len(cv_result) + 1), cv_result['test-rmse-mean'], c="red", label='Test RMSE')
plt.xlabel('Number of Boosting Rounds of T1', fontsize=18)
plt.ylabel('RMSE', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize="x-large")
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\XGBoost Learning Curve of secondary T1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot feature importance
fig, ax = plt.subplots(figsize=(8, 6))
plot_importance(xgb_model, ax=ax)
plt.xlabel('F score of T1', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Feature importance of secondary T1.png', dpi=300, bbox_inches='tight')
plt.show()
