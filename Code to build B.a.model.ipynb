# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor, DMatrix, plot_importance
from skopt import BayesSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import joblib

# %% [markdown]
# # Search for optimal parameters

# %%
# Set random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# %%
# Read data
data_path = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Raw data for CRSS model training.xlsx'
df = pd.read_excel(data_path)

# %%
# Filter out rows where the labels has missing values
df = df.dropna(subset=[df.columns[0]])

# %%
# Convert categorical column to dummy variables
df = pd.get_dummies(df, columns=[df.columns[6]])
df
# Out:
#       B<a>   P<a>   п1<a>  п1<c+a>     T1     C1      d      T        έ  \
# 0    209.0  181.0     NaN    474.0    NaN    NaN    NaN  300.0  0.00025
# 10   150.0   30.0     NaN    120.0  125.0  125.0  30.00  300.0      NaN
# 11    49.0   37.0     NaN    197.0    NaN    NaN    NaN  300.0      NaN
# 12   115.0   55.0     NaN    145.0   95.0  145.0  35.00  300.0  0.00066
# 13   158.0   88.0     NaN    185.0  170.0  255.0  35.00  300.0  0.00066
# ..     ...    ...     ...      ...    ...    ...    ...    ...      ...
# 138  329.9  277.2  1167.0      NaN    NaN    NaN   4.21  300.0  0.00050
# 139  206.0  190.0     NaN    619.0    NaN    NaN    NaN  300.0  0.00500
# 140  392.0  329.0     NaN    874.0    NaN    NaN  20.00  293.0  0.00100
# 141  275.8  206.9   248.2      NaN    NaN    NaN    NaN  300.0  0.00025
# 142  450.0  420.0     NaN      NaN    NaN    NaN   1.00  300.0  0.00010
#
#        `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al     ~Mo    M_C  \
# 0    2.447  2.790  4.00  0.0000  0.012  0.070  0.0150  0.406   0.056   True
# 10   2.447  2.790  4.00  0.0000  0.080  0.010  0.0150  0.058   0.032  False
# 11   2.447  2.790  4.00  0.0000  0.080  0.010  0.0150  0.058   0.032  False
# 12   2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032  False
# 13   2.447  2.790  4.00  0.0000  0.100  0.250  0.0100  1.450   0.040  False
# ..     ...    ...   ...     ...    ...    ...     ...    ...     ...    ...
# 138  2.422  2.755  3.91 -0.0054  0.050  0.100  0.0125  7.212   4.870  False
# 139  2.423  2.761  3.92 -0.0065  0.005  0.100  0.0010  6.713   3.247  False
# 140  2.414  2.754  3.92 -0.0087  0.080  0.015  0.0120  7.006   4.560  False
# 141  2.407  2.743  3.89 -0.0112  0.023  0.140  0.0013  8.712   2.200  False
# 142  2.356  2.770  4.09 -0.0159  0.011  0.110  0.0010  3.678  15.136  False
#
#        M_T
# 0    False
# 10    True
# 11    True
# 12    True
# 13    True
# ..     ...
# 138   True
# 139   True
# 140   True
# 141   True
# 142   True
#
# [122 rows x 20 columns]

# %%
X = df.iloc[:, 6:]
y = df.iloc[:,0]

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
# Define Pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Normalized data
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=random_seed))
])

# %%
# Define parameter space
param_space = {
    'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
    'xgb__n_estimators': (50, 300),
    'xgb__max_depth': (2, 8),
    'xgb__min_child_weight': (1, 10),
    'xgb__subsample': (0.5, 1.0, 'uniform'),
    'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
    'xgb__gamma': (0, 5),
    'xgb__reg_alpha': (0, 1),
    'xgb__reg_lambda': (0, 1)
}

# %%
# Parametric search using BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=pipeline,
    search_spaces=param_space,
    scoring='neg_mean_squared_error',
    cv=KFold(n_splits=5, shuffle=True, random_state=random_seed), 
    n_iter=50,
    n_jobs=-1,
    random_state=random_seed
)

# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                         ('xgb',
#                                          XGBRegressor(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       g...
#               n_jobs=-1, random_state=42, scoring='neg_mean_squared_error',
#               search_spaces={'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
#                              'xgb__gamma': (0, 5),
#                              'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
#                              'xgb__max_depth': (2, 8),
#                              'xgb__min_child_weight': (1, 10),
#                              'xgb__n_estimators': (50, 300),
#                              'xgb__reg_alpha': (0, 1),
#                              'xgb__reg_lambda': (0, 1),
#                              'xgb__subsample': (0.5, 1.0, 'uniform')})

# %%
# Output the best parameters
print("Best params:", bayes_search.best_params_)
print("Best score of train:", bayes_search.best_score_)
print("Best score of test (R²):", r2_score(y_test, bayes_search.predict(X_test)))
# Out:
# Best params: OrderedDict([('xgb__colsample_bytree', 1.0), ('xgb__gamma', 0), ('xgb__learning_rate', 0.022217401411904675), ('xgb__max_depth', 8), ('xgb__min_child_weight', 8), ('xgb__n_estimators', 274), ('xgb__reg_alpha', 0), ('xgb__reg_lambda', 1), ('xgb__subsample', 0.5)])
# Best score of train: -4733.834118742323
# Best score of test (R²): 0.8687132992327015

# %% [markdown]
# # Build the model

# %%
# Get the best parameters for further modeling
best_params = bayes_search.best_params_
xgb_best_params = {k.split('__')[1]: v for k, v in best_params.items()}

# %%
# Convert data to DMatrix format for XGBoost training
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Train XGBoost model using the best parameters
num_round = 500
xgb_model = xgb.train(xgb_best_params, dtrain, num_round, evals=[(dtest, 'eval')], verbose_eval=False)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [16:29:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the model to a file
filename = 'xgboost_model_Ba_0926(original).sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %% [markdown]
# # Predicted results using the original data

# %%
# Predict on the test set
y_pred = xgb_model.predict(dtest)

# %%
# Calculate and print the RMSE and R² on the test set
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f'Test RMSE: {rmse}')
print(f'R² score: {r2}')
# Out:
# Test RMSE: 42.24382186562661
# R² score: 0.8848156176555216

# %%
# Obtain residuals for training and test sets
y_pred_train = xgb_model.predict(dtrain)
residuals_train = y_train.values - y_pred_train
residuals_test = y_test.values - y_pred

# Plot residuals
plt.figure(figsize=(8, 6))
plt.ylim(-100, 100)
plt.scatter(x=y_train, y=residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(x=y_test, y=residuals_test, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of B<a> (MPa)', fontsize=18)
plt.ylabel('Residuals (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Residual plot of original Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of B<a> (MPa)', fontsize=18)
plt.ylabel('Predicted (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='blue', lw=2, linestyle='--')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Predicted vs Actual of original Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Perform cross-validation and obtain performance metrics
cv_result = xgb.cv(xgb_best_params, dtrain, num_round, nfold=5)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [16:29:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cv_result) + 1), cv_result['train-rmse-mean'], c="blue", label='Train RMSE')
plt.plot(range(1, len(cv_result) + 1), cv_result['test-rmse-mean'], c="red", label='Test RMSE')
plt.xlabel('Number of Boosting Rounds of B<a>', fontsize=18)
plt.ylabel('RMSE', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize="x-large")
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\XGBoost Learning Curve of original Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot feature importance
fig, ax = plt.subplots(figsize=(8, 6))
plot_importance(xgb_model, ax=ax)
plt.xlabel('F score of B<a>', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Feature importance of original Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fill in empty data using the initial model

# %%
# Load the saved model for prediction
model_filename = 'xgboost_model_Ba_0926(original).sav'
xgb_model = joblib.load(model_filename)

# %%
# Read the Excel file with missing labels
df_missing = pd.read_excel(data_path)

# %%
# Identify rows with missing labels in the B<a> column
missing_mask = df_missing[df_missing.columns[0]].isna()

# %%
# Filter rows with missing labels
df_to_predict = df_missing[missing_mask]
df_to_predict
# Out:
#      B<a>   P<a>  п1<a>  п1<c+a>     T1     C1  M       d      T           έ  \
# 1     NaN    NaN    NaN    607.5    NaN    NaN  C     NaN  300.0     0.00010
# 2     NaN  139.1    NaN      NaN    NaN    NaN  C    2.80  300.0     0.03000
# 3     NaN  174.7    NaN      NaN    NaN    NaN  C    1.95  300.0     0.00500
# 4     NaN  220.1    NaN      NaN    NaN    NaN  C    0.97  300.0     0.00500
# 5     NaN  239.8    NaN      NaN    NaN    NaN  C    0.98  300.0     0.00500
# 6     NaN  297.1    NaN      NaN    NaN    NaN  C    0.98  300.0     0.00500
# 7     NaN  324.7    NaN      NaN    NaN    NaN  C    0.49  300.0     0.00500
# 8     NaN  346.4    NaN      NaN    NaN    NaN  C    0.49  300.0     0.00500
# 9     NaN  450.9    NaN      NaN    NaN    NaN  C    0.30  300.0     0.00500
# 18    NaN   98.0    NaN    224.0  136.0    NaN  T   20.00  300.0     0.00100
# 24    NaN  106.5    NaN      NaN    NaN    NaN  T     NaN  300.0     0.00025
# 42    NaN    NaN    NaN      NaN    NaN  370.0  C   25.00  300.0     0.00100
# 43    NaN    NaN    NaN      NaN    NaN  390.0  C   25.00  300.0  6000.00000
# 47    NaN   89.0   89.0    288.4    NaN    NaN  T     NaN  300.0     0.00100
# 51    NaN  457.0    NaN   1018.8    NaN    NaN  C  100.00  300.0     0.00020
# 54    NaN  235.0  620.0    565.0  570.0  545.0  C     NaN  298.0     0.00500
# 100   NaN  297.5    NaN      NaN    NaN    NaN  T     NaN  300.0     0.00025
# 101   NaN  329.0    NaN    820.0    NaN    NaN  C     NaN  300.0     0.00025
# 102   NaN  329.0    NaN    558.0    NaN    NaN  T     NaN  300.0     0.00025
# 104   NaN  434.0    NaN      NaN    NaN    NaN  T     NaN  300.0     0.00025
# 119   NaN  376.0    NaN    441.0    NaN    NaN  T   10.00  300.0     0.00017
#
#        `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al    ~Mo
# 1    2.447  2.790  4.00  0.0000  0.080  0.180  0.0150  1.044  0.032
# 2    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 3    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 4    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 5    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 6    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 7    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 8    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 9    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032
# 18   2.447  2.790  4.00  0.0000  0.001  0.001  0.0010  0.006  0.000
# 24   2.447  2.790  4.00  0.0000  0.080  0.180  0.0120  1.044  0.032
# 42   2.447  2.790  4.00  0.0000  0.016  0.060  0.0016  0.348  0.100
# 43   2.447  2.790  4.00  0.0000  0.016  0.060  0.0016  0.348  0.100
# 47   2.447  2.790  4.00  0.0000  0.005  0.140  0.0170  0.812  0.013
# 51   2.447  2.790  4.00  0.0000  0.005  0.790  0.0005  4.582  0.024
# 54   2.421  2.744  3.97 -0.0063  0.040  0.120  0.0005  3.696  3.024
# 100  2.423  2.750  3.90 -0.0077  0.080  0.130  0.0150  6.754  0.000
# 101  2.423  2.750  3.90 -0.0077  0.010  0.080  0.0030  7.064  0.096
# 102  2.423  2.750  3.90 -0.0077  0.010  0.080  0.0030  7.064  0.096
# 104  2.401  2.753  3.93 -0.0114  0.050  0.120  0.0050  6.696  5.024
# 119  2.401  2.753  3.93 -0.0114  0.050  0.120  0.0050  6.696  5.024

# %%
# One-hot encoding for non-numeric feature in df_to_predict
df_to_predict = pd.get_dummies(df_to_predict, columns=[df_to_predict.columns[6]])
df_to_predict
# Out:
#      B<a>   P<a>  п1<a>  п1<c+a>     T1     C1       d      T           έ  \
# 1     NaN    NaN    NaN    607.5    NaN    NaN     NaN  300.0     0.00010
# 2     NaN  139.1    NaN      NaN    NaN    NaN    2.80  300.0     0.03000
# 3     NaN  174.7    NaN      NaN    NaN    NaN    1.95  300.0     0.00500
# 4     NaN  220.1    NaN      NaN    NaN    NaN    0.97  300.0     0.00500
# 5     NaN  239.8    NaN      NaN    NaN    NaN    0.98  300.0     0.00500
# 6     NaN  297.1    NaN      NaN    NaN    NaN    0.98  300.0     0.00500
# 7     NaN  324.7    NaN      NaN    NaN    NaN    0.49  300.0     0.00500
# 8     NaN  346.4    NaN      NaN    NaN    NaN    0.49  300.0     0.00500
# 9     NaN  450.9    NaN      NaN    NaN    NaN    0.30  300.0     0.00500
# 18    NaN   98.0    NaN    224.0  136.0    NaN   20.00  300.0     0.00100
# 24    NaN  106.5    NaN      NaN    NaN    NaN     NaN  300.0     0.00025
# 42    NaN    NaN    NaN      NaN    NaN  370.0   25.00  300.0     0.00100
# 43    NaN    NaN    NaN      NaN    NaN  390.0   25.00  300.0  6000.00000
# 47    NaN   89.0   89.0    288.4    NaN    NaN     NaN  300.0     0.00100
# 51    NaN  457.0    NaN   1018.8    NaN    NaN  100.00  300.0     0.00020
# 54    NaN  235.0  620.0    565.0  570.0  545.0     NaN  298.0     0.00500
# 100   NaN  297.5    NaN      NaN    NaN    NaN     NaN  300.0     0.00025
# 101   NaN  329.0    NaN    820.0    NaN    NaN     NaN  300.0     0.00025
# 102   NaN  329.0    NaN    558.0    NaN    NaN     NaN  300.0     0.00025
# 104   NaN  434.0    NaN      NaN    NaN    NaN     NaN  300.0     0.00025
# 119   NaN  376.0    NaN    441.0    NaN    NaN   10.00  300.0     0.00017
#
#        `Md    `Bo  e/a̅     Δr̅      C      O       H    ~Al    ~Mo    M_C  \
# 1    2.447  2.790  4.00  0.0000  0.080  0.180  0.0150  1.044  0.032   True
# 2    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 3    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 4    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 5    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 6    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 7    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 8    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 9    2.447  2.790  4.00  0.0000  0.080  0.150  0.0150  0.870  0.032   True
# 18   2.447  2.790  4.00  0.0000  0.001  0.001  0.0010  0.006  0.000  False
# 24   2.447  2.790  4.00  0.0000  0.080  0.180  0.0120  1.044  0.032  False
# 42   2.447  2.790  4.00  0.0000  0.016  0.060  0.0016  0.348  0.100   True
# 43   2.447  2.790  4.00  0.0000  0.016  0.060  0.0016  0.348  0.100   True
# 47   2.447  2.790  4.00  0.0000  0.005  0.140  0.0170  0.812  0.013  False
# 51   2.447  2.790  4.00  0.0000  0.005  0.790  0.0005  4.582  0.024   True
# 54   2.421  2.744  3.97 -0.0063  0.040  0.120  0.0005  3.696  3.024   True
# 100  2.423  2.750  3.90 -0.0077  0.080  0.130  0.0150  6.754  0.000  False
# 101  2.423  2.750  3.90 -0.0077  0.010  0.080  0.0030  7.064  0.096   True
# 102  2.423  2.750  3.90 -0.0077  0.010  0.080  0.0030  7.064  0.096  False
# 104  2.401  2.753  3.93 -0.0114  0.050  0.120  0.0050  6.696  5.024  False
# 119  2.401  2.753  3.93 -0.0114  0.050  0.120  0.0050  6.696  5.024  False
#
#        M_T
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 18    True
# 24    True
# 42   False
# 43   False
# 47    True
# 51   False
# 54   False
# 100   True
# 101  False
# 102   True
# 104   True
# 119   True

# %%
# Align the columns of the filled data (df_train) and data to predict (df_to_predict)
df, df_to_predict = df.align(df_to_predict, join='left', axis=1, fill_value=0)

# %%
# Extract features for prediction, excluding the label column
X_to_predict = df_to_predict.iloc[:, 6:].to_numpy()

# %%
# Ensure the feature order matches the trained model
feature_names = df.columns[6:].tolist()

# %%
# Make predictions using the model
d_matrix = xgb.DMatrix(X_to_predict, feature_names=feature_names)
y_pred = xgb_model.predict(d_matrix)

# %%
# Fill the missing labels with the predicted values
df_missing.loc[missing_mask, df_missing.columns[0]] = y_pred

# %%
# Save the dataframe with filled labels back to the Excel file
output_file = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 1 column).xlsx'
df_missing.to_excel(output_file, index=False)

# %% [markdown]
# # Rebulid model using secondary data

# %%
# Read data again
data_path = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 1 column).xlsx'
df = pd.read_excel(data_path)

# %%
# Convert categorical column to dummy variables
df = pd.get_dummies(df, columns=[df.columns[6]])
df
# Out:
#            B<a>   P<a>   п1<a>  п1<c+a>  T1  C1      d      T        έ    `Md  \
# 0    209.000000  181.0     NaN    474.0 NaN NaN    NaN  300.0  0.00025  2.447
# 1    238.396133    NaN     NaN    607.5 NaN NaN    NaN  300.0  0.00010  2.447
# 2    230.900131  139.1     NaN      NaN NaN NaN   2.80  300.0  0.03000  2.447
# 3    234.993423  174.7     NaN      NaN NaN NaN   1.95  300.0  0.00500  2.447
# 4    234.424667  220.1     NaN      NaN NaN NaN   0.97  300.0  0.00500  2.447
# ..          ...    ...     ...      ...  ..  ..    ...    ...      ...    ...
# 138  329.900000  277.2  1167.0      NaN NaN NaN   4.21  300.0  0.00050  2.422
# 139  206.000000  190.0     NaN    619.0 NaN NaN    NaN  300.0  0.00500  2.423
# 140  392.000000  329.0     NaN    874.0 NaN NaN  20.00  293.0  0.00100  2.414
# 141  275.800000  206.9   248.2      NaN NaN NaN    NaN  300.0  0.00025  2.407
# 142  450.000000  420.0     NaN      NaN NaN NaN   1.00  300.0  0.00010  2.356
#
#        `Bo  e/a̅     Δr̅      C      O       H    ~Al     ~Mo    M_C    M_T
# 0    2.790  4.00  0.0000  0.012  0.070  0.0150  0.406   0.056   True  False
# 1    2.790  4.00  0.0000  0.080  0.180  0.0150  1.044   0.032   True  False
# 2    2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032   True  False
# 3    2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032   True  False
# 4    2.790  4.00  0.0000  0.080  0.150  0.0150  0.870   0.032   True  False
# ..     ...   ...     ...    ...    ...     ...    ...     ...    ...    ...
# 138  2.755  3.91 -0.0054  0.050  0.100  0.0125  7.212   4.870  False   True
# 139  2.761  3.92 -0.0065  0.005  0.100  0.0010  6.713   3.247  False   True
# 140  2.754  3.92 -0.0087  0.080  0.015  0.0120  7.006   4.560  False   True
# 141  2.743  3.89 -0.0112  0.023  0.140  0.0013  8.712   2.200  False   True
# 142  2.770  4.09 -0.0159  0.011  0.110  0.0010  3.678  15.136  False   True
#
# [143 rows x 20 columns]

# %%
X = df.iloc[:, 6:]
y = df.iloc[:,0]

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
# Define Pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Normalized data
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=random_seed))
])

# %%
# Define parameter space
param_space = {
    'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
    'xgb__n_estimators': (50, 300),
    'xgb__max_depth': (2, 8),
    'xgb__min_child_weight': (1, 10),
    'xgb__subsample': (0.5, 1.0, 'uniform'),
    'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
    'xgb__gamma': (0, 5),
    'xgb__reg_alpha': (0, 1),
    'xgb__reg_lambda': (0, 1)
}

# %%
# Parametric search using BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=pipeline,
    search_spaces=param_space,
    scoring='neg_mean_squared_error',
    cv=KFold(n_splits=5, shuffle=True, random_state=random_seed), 
    n_iter=50,
    n_jobs=-1,
    random_state=random_seed
)

# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                         ('xgb',
#                                          XGBRegressor(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       g...
#               n_jobs=-1, random_state=42, scoring='neg_mean_squared_error',
#               search_spaces={'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
#                              'xgb__gamma': (0, 5),
#                              'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
#                              'xgb__max_depth': (2, 8),
#                              'xgb__min_child_weight': (1, 10),
#                              'xgb__n_estimators': (50, 300),
#                              'xgb__reg_alpha': (0, 1),
#                              'xgb__reg_lambda': (0, 1),
#                              'xgb__subsample': (0.5, 1.0, 'uniform')})

# %%
# Output the best parameters
print("Best params:", bayes_search.best_params_)
print("Best score of train:", bayes_search.best_score_)
print("Best score of test (R²):", r2_score(y_test, bayes_search.predict(X_test)))
# Out:
# Best params: OrderedDict([('xgb__colsample_bytree', 0.9777389931549642), ('xgb__gamma', 4), ('xgb__learning_rate', 0.1938811514231446), ('xgb__max_depth', 4), ('xgb__min_child_weight', 4), ('xgb__n_estimators', 103), ('xgb__reg_alpha', 0), ('xgb__reg_lambda', 0), ('xgb__subsample', 0.7971894567956928)])
# Best score of train: -2279.2611468304567
# Best score of test (R²): 0.743152824588585

# %%
# Get the best parameters for further modeling
best_params = bayes_search.best_params_
xgb_best_params = {k.split('__')[1]: v for k, v in best_params.items()}

# %%
# Convert data to DMatrix format for XGBoost training
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Train XGBoost model using the best parameters
num_round = 500
xgb_model = xgb.train(xgb_best_params, dtrain, num_round, evals=[(dtest, 'eval')], verbose_eval=False)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [16:32:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the model to another file
filename = 'xgboost_model_Ba_0926(secondary).sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %%
# Predict on the test set
y_pred = xgb_model.predict(dtest)

# %%
# Calculate and print the RMSE and R² on the test set
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f'Test RMSE: {rmse}')
print(f'R² score: {r2}')
# Out:
# Test RMSE: 73.63747269274913
# R² score: 0.7026559987604781

# %%
# Obtain residuals for training and test sets
y_pred_train = xgb_model.predict(dtrain)
residuals_train = y_train.values - y_pred_train
residuals_test = y_test.values - y_pred

# Plot residuals
plt.figure(figsize=(8, 6))
plt.ylim(-100, 100)
plt.scatter(x=y_train, y=residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(x=y_test, y=residuals_test, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of B<a> (MPa)', fontsize=18)
plt.ylabel('Residuals (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Residual plot of secondary Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of B<a> (MPa)', fontsize=18)
plt.ylabel('Predicted (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='blue', lw=2, linestyle='--')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Predicted vs Actual of secondary Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Perform cross-validation and obtain performance metrics
cv_result = xgb.cv(xgb_best_params, dtrain, num_round, nfold=5)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [16:32:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cv_result) + 1), cv_result['train-rmse-mean'], c="blue", label='Train RMSE')
plt.plot(range(1, len(cv_result) + 1), cv_result['test-rmse-mean'], c="red", label='Test RMSE')
plt.xlabel('Number of Boosting Rounds of B<a>', fontsize=18)
plt.ylabel('RMSE', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize="x-large")
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\XGBoost Learning Curve of secondary Ba.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot feature importance
fig, ax = plt.subplots(figsize=(8, 6))
plot_importance(xgb_model, ax=ax)
plt.xlabel('F score of B<a>', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Feature importance of secondary Ba.png', dpi=300, bbox_inches='tight')
plt.show()
