# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor, DMatrix, plot_importance
from skopt import BayesSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import joblib

# %% [markdown]
# # Search for optimal parameters

# %%
# Set random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# %%
# Read data
data_path = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 3 columns).xlsx'
df = pd.read_excel(data_path)

# %%
# Filter out rows where the labels has missing values
df = df.dropna(subset=[df.columns[3]])

# %%
# Convert categorical column to dummy variables
df = pd.get_dummies(df, columns=[df.columns[6]])
df
# Out:
#            B<a>        P<a>       п1<a>  п1<c+a>     T1     C1     d      T  \
# 0    209.000000  181.000000  129.709366    474.0    NaN    NaN   NaN  300.0
# 1    238.396133  103.283859  100.437004    607.5    NaN    NaN   NaN  300.0
# 10   150.000000   30.000000   75.252411    120.0  125.0  125.0  30.0  300.0
# 11    49.000000   37.000000   78.109505    197.0    NaN    NaN   NaN  300.0
# 12   115.000000   55.000000   99.119995    145.0   95.0  145.0  35.0  300.0
# ..          ...         ...         ...      ...    ...    ...   ...    ...
# 120  444.000000  392.000000  404.000000    631.0    NaN    NaN  10.0  300.0
# 121  330.000000  410.000000  492.674988    690.0    NaN    NaN   NaN  300.0
# 127  365.000000  345.000000  511.044373    619.8    NaN    NaN  10.0  300.0
# 139  206.000000  190.000000  425.678223    619.0    NaN    NaN   NaN  300.0
# 140  392.000000  329.000000  271.167480    874.0    NaN    NaN  20.0  293.0
#
#            έ    `Md    `Bo  e/a̅     Δr̅      C      O      H    ~Al    ~Mo  \
# 0    0.00025  2.447  2.790  4.00  0.0000  0.012  0.070  0.015  0.406  0.056
# 1    0.00010  2.447  2.790  4.00  0.0000  0.080  0.180  0.015  1.044  0.032
# 10       NaN  2.447  2.790  4.00  0.0000  0.080  0.010  0.015  0.058  0.032
# 11       NaN  2.447  2.790  4.00  0.0000  0.080  0.010  0.015  0.058  0.032
# 12   0.00066  2.447  2.790  4.00  0.0000  0.080  0.150  0.015  0.870  0.032
# ..       ...    ...    ...   ...     ...    ...    ...    ...    ...    ...
# 120  0.00017  2.401  2.753  3.93 -0.0114  0.050  0.120  0.005  6.696  5.024
# 121  0.00200  2.398  2.753  3.94 -0.0120  0.050  0.120  0.005  6.796  5.744
# 127  0.00010  2.424  2.756  3.91 -0.0050  0.050  0.131  0.125  7.272  4.767
# 139  0.00500  2.423  2.761  3.92 -0.0065  0.005  0.100  0.001  6.713  3.247
# 140  0.00100  2.414  2.754  3.92 -0.0087  0.080  0.015  0.012  7.006  4.560
#
#        M_C    M_T
# 0     True  False
# 1     True  False
# 10   False   True
# 11   False   True
# 12   False   True
# ..     ...    ...
# 120   True  False
# 121  False   True
# 127  False   True
# 139  False   True
# 140  False   True
#
# [74 rows x 20 columns]

# %%
X = df.iloc[:, 6:]
y = df.iloc[:,3]

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
# Define Pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Normalized data
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=random_seed))
])

# %%
# Define parameter space
param_space = {
    'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
    'xgb__n_estimators': (50, 300),
    'xgb__max_depth': (2, 8),
    'xgb__min_child_weight': (1, 10),
    'xgb__subsample': (0.5, 1.0, 'uniform'),
    'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
    'xgb__gamma': (0, 5),
    'xgb__reg_alpha': (0, 1),
    'xgb__reg_lambda': (0, 1)
}

# %%
# Parametric search using BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=pipeline,
    search_spaces=param_space,
    scoring='neg_mean_squared_error',
    cv=KFold(n_splits=5, shuffle=True, random_state=random_seed), 
    n_iter=50,
    n_jobs=-1,
    random_state=random_seed
)

# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                         ('xgb',
#                                          XGBRegressor(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       g...
#               n_jobs=-1, random_state=42, scoring='neg_mean_squared_error',
#               search_spaces={'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
#                              'xgb__gamma': (0, 5),
#                              'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
#                              'xgb__max_depth': (2, 8),
#                              'xgb__min_child_weight': (1, 10),
#                              'xgb__n_estimators': (50, 300),
#                              'xgb__reg_alpha': (0, 1),
#                              'xgb__reg_lambda': (0, 1),
#                              'xgb__subsample': (0.5, 1.0, 'uniform')})

# %%
# Output the best parameters
print("Best params:", bayes_search.best_params_)
print("Best score of train:", bayes_search.best_score_)
print("Best score of test (R²):", r2_score(y_test, bayes_search.predict(X_test)))
# Out:
# Best params: OrderedDict([('xgb__colsample_bytree', 0.5), ('xgb__gamma', 5), ('xgb__learning_rate', 0.04317514103117562), ('xgb__max_depth', 3), ('xgb__min_child_weight', 5), ('xgb__n_estimators', 102), ('xgb__reg_alpha', 1), ('xgb__reg_lambda', 0), ('xgb__subsample', 0.9228772256759575)])
# Best score of train: -30635.477085850805
# Best score of test (R²): 0.5562924665726643

# %% [markdown]
# # Build the model

# %%
# Get the best parameters for further modeling
best_params = bayes_search.best_params_
xgb_best_params = {k.split('__')[1]: v for k, v in best_params.items()}

# %%
# Convert data to DMatrix format for XGBoost training
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Train XGBoost model using the best parameters
num_round = 500
xgb_model = xgb.train(xgb_best_params, dtrain, num_round, evals=[(dtest, 'eval')], verbose_eval=False)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:42:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the model to a file
filename = 'xgboost_model_Π1c+a_0926(original).sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %% [markdown]
# # Predicted results using the original data

# %%
# Predict on the test set
y_pred = xgb_model.predict(dtest)

# %%
# Calculate and print the RMSE and R² on the test set
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f'Test RMSE: {rmse}')
print(f'R² score: {r2}')
# Out:
# Test RMSE: 169.79330996090692
# R² score: 0.6408684638802176

# %%
# Obtain residuals for training and test sets
y_pred_train = xgb_model.predict(dtrain)
residuals_train = y_train.values - y_pred_train
residuals_test = y_test.values - y_pred

# Plot residuals
plt.figure(figsize=(8, 6))
plt.ylim(-150, 150)
plt.scatter(x=y_train, y=residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(x=y_test, y=residuals_test, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of Π1<c+a> (MPa)', fontsize=18)
plt.ylabel('Residuals (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Residual plot of original Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of Π1<c+a> (MPa)', fontsize=18)
plt.ylabel('Predicted (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='blue', lw=2, linestyle='--')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Predicted vs Actual of original Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Perform cross-validation and obtain performance metrics
cv_result = xgb.cv(xgb_best_params, dtrain, num_round, nfold=5)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:42:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cv_result) + 1), cv_result['train-rmse-mean'], c="blue", label='Train RMSE')
plt.plot(range(1, len(cv_result) + 1), cv_result['test-rmse-mean'], c="red", label='Test RMSE')
plt.xlabel('Number of Boosting Rounds of Π1<c+a>', fontsize=18)
plt.ylabel('RMSE', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize="x-large")
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\XGBoost Learning Curve of original Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot feature importance
fig, ax = plt.subplots(figsize=(8, 6))
plot_importance(xgb_model, ax=ax)
plt.xlabel('F score of Π1<c+a>', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Feature importance of original Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fill in empty data using the initial model

# %%
# Load the saved model for prediction
model_filename = 'xgboost_model_Π1c+a_0926(original).sav'
xgb_model = joblib.load(model_filename)

# %%
# Read the Excel file with missing labels
df_missing = pd.read_excel(data_path)

# %%
# Identify rows with missing labels in the B<a> column
missing_mask = df_missing[df_missing.columns[3]].isna()

# %%
# Filter rows with missing labels
df_to_predict = df_missing[missing_mask]
df_to_predict
# Out:
#            B<a>   P<a>        п1<a>  п1<c+a>  T1  C1  M     d      T        έ  \
# 2    230.900131  139.1   803.092407      NaN NaN NaN  C  2.80  300.0  0.03000
# 3    234.993423  174.7   322.611359      NaN NaN NaN  C  1.95  300.0  0.00500
# 4    234.424667  220.1   322.611359      NaN NaN NaN  C  0.97  300.0  0.00500
# 5    234.424667  239.8   322.611359      NaN NaN NaN  C  0.98  300.0  0.00500
# 6    234.424667  297.1   322.611359      NaN NaN NaN  C  0.98  300.0  0.00500
# ..          ...    ...          ...      ...  ..  .. ..   ...    ...      ...
# 136  336.000000  300.0  1359.000000      NaN NaN NaN  T  3.42  300.0  0.00050
# 137  311.800000  262.0  1118.700000      NaN NaN NaN  T  4.14  300.0  0.00050
# 138  329.900000  277.2  1167.000000      NaN NaN NaN  T  4.21  300.0  0.00050
# 141  275.800000  206.9   248.200000      NaN NaN NaN  T   NaN  300.0  0.00025
# 142  450.000000  420.0  1028.751587      NaN NaN NaN  T  1.00  300.0  0.00010
#
#        `Md    `Bo  e/a̅     Δr̅      C     O       H    ~Al     ~Mo
# 2    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032
# 3    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032
# 4    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032
# 5    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032
# 6    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032
# ..     ...    ...   ...     ...    ...   ...     ...    ...     ...
# 136  2.422  2.755  3.91 -0.0054  0.050  0.10  0.0125  7.212   4.870
# 137  2.422  2.755  3.91 -0.0054  0.050  0.10  0.0125  7.212   4.870
# 138  2.422  2.755  3.91 -0.0054  0.050  0.10  0.0125  7.212   4.870
# 141  2.407  2.743  3.89 -0.0112  0.023  0.14  0.0013  8.712   2.200
# 142  2.356  2.770  4.09 -0.0159  0.011  0.11  0.0010  3.678  15.136
#
# [69 rows x 19 columns]

# %%
# One-hot encoding for non-numeric feature in df_to_predict
df_to_predict = pd.get_dummies(df_to_predict, columns=[df_to_predict.columns[6]])
df_to_predict
# Out:
#            B<a>   P<a>        п1<a>  п1<c+a>  T1  C1     d      T        έ  \
# 2    230.900131  139.1   803.092407      NaN NaN NaN  2.80  300.0  0.03000
# 3    234.993423  174.7   322.611359      NaN NaN NaN  1.95  300.0  0.00500
# 4    234.424667  220.1   322.611359      NaN NaN NaN  0.97  300.0  0.00500
# 5    234.424667  239.8   322.611359      NaN NaN NaN  0.98  300.0  0.00500
# 6    234.424667  297.1   322.611359      NaN NaN NaN  0.98  300.0  0.00500
# ..          ...    ...          ...      ...  ..  ..   ...    ...      ...
# 136  336.000000  300.0  1359.000000      NaN NaN NaN  3.42  300.0  0.00050
# 137  311.800000  262.0  1118.700000      NaN NaN NaN  4.14  300.0  0.00050
# 138  329.900000  277.2  1167.000000      NaN NaN NaN  4.21  300.0  0.00050
# 141  275.800000  206.9   248.200000      NaN NaN NaN   NaN  300.0  0.00025
# 142  450.000000  420.0  1028.751587      NaN NaN NaN  1.00  300.0  0.00010
#
#        `Md    `Bo  e/a̅     Δr̅      C     O       H    ~Al     ~Mo    M_C  \
# 2    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032   True
# 3    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032   True
# 4    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032   True
# 5    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032   True
# 6    2.447  2.790  4.00  0.0000  0.080  0.15  0.0150  0.870   0.032   True
# ..     ...    ...   ...     ...    ...   ...     ...    ...     ...    ...
# 136  2.422  2.755  3.91 -0.0054  0.050  0.10  0.0125  7.212   4.870  False
# 137  2.422  2.755  3.91 -0.0054  0.050  0.10  0.0125  7.212   4.870  False
# 138  2.422  2.755  3.91 -0.0054  0.050  0.10  0.0125  7.212   4.870  False
# 141  2.407  2.743  3.89 -0.0112  0.023  0.14  0.0013  8.712   2.200  False
# 142  2.356  2.770  4.09 -0.0159  0.011  0.11  0.0010  3.678  15.136  False
#
#        M_T
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# ..     ...
# 136   True
# 137   True
# 138   True
# 141   True
# 142   True
#
# [69 rows x 20 columns]

# %%
# Align the columns of the filled data (df_train) and data to predict (df_to_predict)
df, df_to_predict = df.align(df_to_predict, join='left', axis=1, fill_value=0)

# %%
# Extract features for prediction, excluding the label column
X_to_predict = df_to_predict.iloc[:, 6:].to_numpy()

# %%
# Ensure the feature order matches the trained model
feature_names = df.columns[6:].tolist()

# %%
# Make predictions using the model
d_matrix = xgb.DMatrix(X_to_predict, feature_names=feature_names)
y_pred = xgb_model.predict(d_matrix)

# %%
# Fill the missing labels with the predicted values
df_missing.loc[missing_mask, df_missing.columns[3]] = y_pred

# %%
# Save the dataframe with filled labels back to the Excel file
output_file = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 4 columns).xlsx'
df_missing.to_excel(output_file, index=False)

# %% [markdown]
# # Rebulid model using secondary data

# %%
# Read data again
data_path = r'D:\Desktop\Researchs\CRSS of Ti\Training data\Training data (Filled 4 columns).xlsx'
df = pd.read_excel(data_path)

# %%
# Convert categorical column to dummy variables
df = pd.get_dummies(df, columns=[df.columns[6]])

# %%
X = df.iloc[:, 6:]
y = df.iloc[:,3]

# %%
# Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
# Define Pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Normalized data
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=random_seed))
])

# %%
# Define parameter space
param_space = {
    'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
    'xgb__n_estimators': (50, 300),
    'xgb__max_depth': (2, 8),
    'xgb__min_child_weight': (1, 10),
    'xgb__subsample': (0.5, 1.0, 'uniform'),
    'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
    'xgb__gamma': (0, 5),
    'xgb__reg_alpha': (0, 1),
    'xgb__reg_lambda': (0, 1)
}

# %%
# Parametric search using BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=pipeline,
    search_spaces=param_space,
    scoring='neg_mean_squared_error',
    cv=KFold(n_splits=5, shuffle=True, random_state=random_seed), 
    n_iter=50,
    n_jobs=-1,
    random_state=random_seed
)

# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                         ('xgb',
#                                          XGBRegressor(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       g...
#               n_jobs=-1, random_state=42, scoring='neg_mean_squared_error',
#               search_spaces={'xgb__colsample_bytree': (0.5, 1.0, 'uniform'),
#                              'xgb__gamma': (0, 5),
#                              'xgb__learning_rate': (0.01, 0.3, 'log-uniform'),
#                              'xgb__max_depth': (2, 8),
#                              'xgb__min_child_weight': (1, 10),
#                              'xgb__n_estimators': (50, 300),
#                              'xgb__reg_alpha': (0, 1),
#                              'xgb__reg_lambda': (0, 1),
#                              'xgb__subsample': (0.5, 1.0, 'uniform')})

# %%
# Output the best parameters
print("Best params:", bayes_search.best_params_)
print("Best score of train:", bayes_search.best_score_)
print("Best score of test (R²):", r2_score(y_test, bayes_search.predict(X_test)))
# Out:
# Best params: OrderedDict([('xgb__colsample_bytree', 0.8168221928224102), ('xgb__gamma', 5), ('xgb__learning_rate', 0.29999999999999993), ('xgb__max_depth', 4), ('xgb__min_child_weight', 7), ('xgb__n_estimators', 167), ('xgb__reg_alpha', 0), ('xgb__reg_lambda', 0), ('xgb__subsample', 0.6940341204862052)])
# Best score of train: -14516.388465398297
# Best score of test (R²): 0.7248623314037226

# %%
# Get the best parameters for further modeling
best_params = bayes_search.best_params_
xgb_best_params = {k.split('__')[1]: v for k, v in best_params.items()}

# %%
# Convert data to DMatrix format for XGBoost training
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Train XGBoost model using the best parameters
num_round = 500
xgb_model = xgb.train(xgb_best_params, dtrain, num_round, evals=[(dtest, 'eval')], verbose_eval=False)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:44:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Save the model to another file
filename = 'xgboost_model_Π1c+a_0926(secondary).sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %%
# Predict on the test set
y_pred = xgb_model.predict(dtest)

# %%
# Calculate and print the RMSE and R² on the test set
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)
print(f'Test RMSE: {rmse}')
print(f'R² score: {r2}')
# Out:
# Test RMSE: 141.9184681927435
# R² score: 0.6370293820088571

# %%
# Obtain residuals for training and test sets
y_pred_train = xgb_model.predict(dtrain)
residuals_train = y_train.values - y_pred_train
residuals_test = y_test.values - y_pred

# Plot residuals
plt.figure(figsize=(8, 6))
plt.ylim(-150, 150)
plt.scatter(x=y_train, y=residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(x=y_test, y=residuals_test, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of Π1<c+a> (MPa)', fontsize=18)
plt.ylabel('Residuals (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Residual plot of secondary Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='red', marker='s', label='Test data')
plt.xlabel('CRSS of Π1<c+a> (MPa)', fontsize=18)
plt.ylabel('Predicted (MPa)', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='blue', lw=2, linestyle='--')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Predicted vs Actual of secondary Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Perform cross-validation and obtain performance metrics
cv_result = xgb.cv(xgb_best_params, dtrain, num_round, nfold=5)
# Out:
# C:\Users\25111\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:160: UserWarning: [15:44:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Plot learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cv_result) + 1), cv_result['train-rmse-mean'], c="blue", label='Train RMSE')
plt.plot(range(1, len(cv_result) + 1), cv_result['test-rmse-mean'], c="red", label='Test RMSE')
plt.xlabel('Number of Boosting Rounds of Π1<c+a>', fontsize=18)
plt.ylabel('RMSE', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize="x-large")
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\XGBoost Learning Curve of secondary Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot feature importance
fig, ax = plt.subplots(figsize=(8, 6))
plot_importance(xgb_model, ax=ax)
plt.xlabel('F score of Π1<c+a>', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('')
plt.savefig(r'D:\Desktop\Researchs\CRSS of Ti\Training results\Feature importance of secondary Π1c+a.png', dpi=300, bbox_inches='tight')
plt.show()
